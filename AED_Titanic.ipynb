# %% [markdown]
# # _*TALLER INTELIGENCIA DE NEGOCIOS*_ (Dataset Titanic)
# ## _Integrantes_
# - Diego Olmedo
# - Nicolas Wilches
# - Mariana Chacon
# - Juan Mateus

# %% [markdown]
# ## Cargar Datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/juanpablo130502/TallerDatasetTitanic_BI/refs/heads/main/Data/titanic_DS_19022025.csv"
df = pd.read_csv(url, delimiter=";")
print(df.head(5))
# Out:
#    PassengerId  Pclass         Name     Sex   Age  SibSp  Parch    Ticket  \
# 0            1       3  Passenger 1  female  33.2      3      3  Ticket 1
# 1            2       1  Passenger 2  female  31.8      2      0  Ticket 2
# 2            3       3  Passenger 3  female  65.0      4      3  Ticket 3
# 3            4       3  Passenger 4    male  33.2      1      0  Ticket 4
# 4            5       1  Passenger 5  female   3.1      3      4  Ticket 5
#
#                      Fare Cabin Embarked  Survived
# 0  13.898.392.995.281.800   E34        C         1
# 1   1.943.948.094.416.680   B12        C         0
# 2   3.045.253.030.073.890   NaN        Q         0
# 3  20.089.369.077.444.000   NaN        S         0
# 4   1.528.427.179.068.370   D56        Q         0

# %% [markdown]
# ## Verificamos Nombres de columnas y se corrigen posibles rrores en la BD

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")
print("Columnas:", df.columns.tolist())
# Out:
# Columnas: ['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived']

# %% [markdown]
# ## Resumen Estadistico

# %%
display(df.describe())
# Out:
#        PassengerId       Pclass          Age        SibSp        Parch  \
# count  2224.000000  2224.000000  2224.000000  2224.000000  2224.000000
# mean   1112.500000     1.976169    41.181969     1.985612     1.938399
# std     642.157821     0.818075    22.661251     1.412867     1.433887
# min       1.000000     1.000000     1.000000     0.000000     0.000000
# 25%     556.750000     1.000000    22.075000     1.000000     1.000000
# 50%    1112.500000     2.000000    42.050000     2.000000     2.000000
# 75%    1668.250000     3.000000    60.400000     3.000000     3.000000
# max    2224.000000     3.000000    80.000000     4.000000     4.000000
#
#          Survived
# count  2224.00000
# mean      0.34982
# std       0.47702
# min       0.00000
# 25%       0.00000
# 50%       0.00000
# 75%       1.00000
# max       1.00000

# %% [markdown]
# ## Verificamos Valores Nulos

# %%
print("Valores nulos:")
display(df.isnull().sum())
# Out:
# Valores nulos:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          305
# Embarked         0
# Survived         0
# dtype: int64

# %% [markdown]
# ## Histograma de las Variables numericas

# %%
df.select_dtypes(include=["number"]).hist(bins=15, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Distribucion de la edad de los pasajeros

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["Age"].dropna(), bins=20, kde=True, color="blue")
plt.title("Distribución de la Edad de los Pasajeros")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ## Matriz de Correlación

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matriz de Correlación")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
#       3 plt.title("Matriz de Correlación")
#       4 plt.show()
#
# NameError: name 'df_numeric' is not defined

# %% [markdown]
# ## Analisis Variable "Survive"

# %%
sns.countplot(x="Survived", data=df, palette="Set1")
plt.title("Distribución de Supervivencia")
plt.xlabel("Supervivió")
plt.ylabel("Cantidad")
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_27876\1994359597.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Survived", data=df, palette="Set1")

# %% [markdown]
# ## Relacion entre Clase de pasajero y Tasa de Superviviencia

# %%
plt.figure(figsize=(12, 5))
sns.barplot(x="Pclass", y="Survived", data=df, ci=None, palette="muted")
plt.title("Supervivencia según Clase del Pasajero")
plt.xlabel("Clase")
plt.ylabel("Tasa de Supervivencia")
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_27876\3045301281.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Pclass", y="Survived", data=df, ci=None, palette="muted")
# C:\Users\nicol\AppData\Local\Temp\ipykernel_27876\3045301281.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Pclass", y="Survived", data=df, ci=None, palette="muted")

# %% [markdown]
# ## Analisis Relacion entre Sexo y Tasa de Supervivencia

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x="Sex", y="Survived", data=df, ci=None, palette="pastel")
plt.title("Supervivencia según Sexo")
plt.xlabel("Sexo")
plt.ylabel("Tasa de Supervivencia")
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_27876\1830449564.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Sex", y="Survived", data=df, ci=None, palette="pastel")
# C:\Users\nicol\AppData\Local\Temp\ipykernel_27876\1830449564.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Sex", y="Survived", data=df, ci=None, palette="pastel")

# %% [markdown]
# ## Exploración de los datos faltantes

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Mapa de valores faltantes")
plt.show()

# %% [markdown]
# ## BoxPlot para detectar los Outliers

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[['Age', 'Fare', 'SibSp', 'Parch']])
plt.title("Boxplot de variables numéricas")
plt.show()
